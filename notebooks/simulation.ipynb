# %% [markdown]
# # 🎲 Generación y Simulación de Datos - FinanceAI
#
# Este notebook está destinado exclusivamente a la simulación matemática y generación de datos sintéticos de usuarios y transacciones. Su salida alimentará tanto al análisis de datos como al entrenamiento de los modelos.
#
# ---
#
# ## ⚙️ 1. Preparación del Entorno
# *Importación de librerías para la generación aleatoria (Pandas, Numpy).*

# %%
import pandas as pd
import numpy as np

SEED = 42
np.random.seed(SEED)

# %% [markdown]
# ## 👤 2. Simulación de Usuarios
# *Lógica para simular 1000 usuarios con nombre, ingresos, endeudamiento, ahorro y perfil financiero.*

# %%
# Escribe aquí la lógica de simulación de usuarios

# %% [markdown]
# ## 💸 3. Simulación de Transacciones (Gastos e Ingresos)
# *Generación de transacciones basadas en texto vinculadas a los usuarios mediante ID, incluyendo sueldos.*

# %%
# Escribe aquí la lógica de generación de movimientos

# %% [markdown]
# ## 💾 4. Exportación de Datasets Semilla
# *Escritura de los DataFrames en la carpeta local data/ en formatos CSV y JSON.*

# %%
# df_usuarios.to_json('data/usuarios.json', orient='records', force_ascii=False, indent=2)
# df_transacciones.to_json('data/transacciones.json', orient='records', force_ascii=False, indent=2)
