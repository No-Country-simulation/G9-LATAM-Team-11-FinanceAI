# %% [markdown]
# # 🧠 Entrenamiento y Exportación de Modelos - FinanceAI
#
# Este notebook está destinado al procesamiento de datos, entrenamiento del modelo NLP (para clasificar transacciones), el modelo de perfil financiero (Random Forest), y la posterior conversión a formato binario interoperable (.onnx).
#
# ---
#
# ## ⚙️ 1. Preparación del Entorno
# *Carga de librerías esenciales y configuración de constantes.*

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

SEED = 42
np.random.seed(SEED)

# %% [markdown]
# ## 🏷️ 2. Modelo 1: Clasificación de Transacciones (NLP)
# *Desarrollo del preprocesador de texto (TF-IDF) y el clasificador de gastos.*

# %%
# Escribe tu código aquí

# %% [markdown]
# ## 📊 3. Modelo 2: Clasificación de Perfil Financiero
# *Entrenamiento del clasificador basado en variables numéricas y categóricas del usuario.*

# %%
# Escribe tu código aquí

# %% [markdown]
# ## 🎯 4. Evaluación de Modelos
# *Visualización del reporte de clasificación y matriz de confusión.*

# %%
# Escribe tu código aquí

# %% [markdown]
# ## 🔌 5. Exportación a Formato ONNX
# *Conversión de los pipelines scikit-learn entrenados a binarios .onnx en shared-models/.*

# %%
# Escribe tu código aquí
